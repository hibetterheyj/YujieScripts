# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import cv2

from skimage import measure, color
from os import listdir 

plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.cmap'] = 'gray'

from yujie_img import Image

# %%
# conda install -c conda-forge scikit-image
# conda install -c conda-forge matplotlib
# conda install -c conda-forge opencv
# conda install -c anaconda numpy

# %%
img_brain = Image(path='./images/brain.png')
img_brain.draw_img('g')
img_brain.draw_hist()
img_brain.get_thres(5, 100)
img_brain.draw_img('t')

# %%
img_apple = Image(path='./images/apples.jpg')
img_apple.draw_img()

# %%
img_apple.draw_img('c', [18.5, 10.5])

# %% [markdown]
# - read from numpy array

# %%
img_apples = cv2.imread('./images/apples.jpg')
apples_g = Image(img_apples[:,:,1], intensity=True)
apples_g.draw_img()
apples_g.draw_hist()

# %%
apples_g.get_thres(20, 70)
apples_g.draw_img('t')
